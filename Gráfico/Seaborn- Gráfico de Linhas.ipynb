# %% [markdown]
# <h1>Gráfico de Linhas</h1>

# %% [markdown]
# <i>
# • Importe o Pandas<br>
# • Importe o Matplotlib<br>
# • Importe o Seaborn<br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

dataset = pd.read_csv('ipeadata_BPM6.csv',skiprows=0, sep=',', encoding='utf-8')
display(dataset.head(4))
# Out:
#    Data  \
# 0  1995
# 1  1996
# 2  1997
# 3  1998
#
#    Balanço de pagamentos - ativos de reserva - US$ - Banco Central do Brasil- Balanço de Pagamentos (BPM6) (BCB / BP (BPM6)) - BPAG_AR  \
# 0                                       12918.900000
# 1                                        8666.100000
# 2                                       -7907.159127
# 3                                       -7970.207388
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %% [markdown]
# <h3> Criando variáveis X e Y </h3>

# %%
x = dataset['Data']
y = dataset['Balanço de pagamentos - ativos de reserva - US$ - Banco Central do Brasil- Balanço de Pagamentos (BPM6) (BCB / BP (BPM6)) - BPAG_AR']

# %% [markdown]
# <h3> Criando uma função para configuração básica do gráfico <h3>

# %%
 def configuracao(grafico1):
    plt.figure(figsize=(15,8))
    plt.title('Balanço de pagamentos - ativos de reserva por ano', fontsize='14')
    plt.ylabel('Balanço de pagamentos - ativos de reserva ', fontsize='14')
    plt.xlabel('Ano', fontsize='14')
    sns.set_theme(style="darkgrid")
    
def configuracao(grafico2):
     
    plt.figure(figsize=(15,8))
    plt.title('Balanço de pagamentos - ativos de reserva por ano', fontsize='14')
    plt.ylabel('Balanço de pagamentos - ativos de reserva ', fontsize='14')
    plt.xlabel('Ano', fontsize='14')
    sns.set_theme(style="whitegrid")

# %% [markdown]
# <h3> Modelo 1 </h3>

# %%
configuracao('grafico1')
sns.lineplot(data=dataset,
             x=x,
             y=y,
             color='#1E90FF',
             drawstyle='default',
             marker='o', 
             markerfacecolor='#4169E1',
             markersize=8,
             fillstyle='full'
)
# Out:
# <AxesSubplot:title={'center':'Balanço de pagamentos - ativos de reserva por ano'}, xlabel='Ano', ylabel='Balanço de pagamentos - ativos de reserva '>

# %% [markdown]
# <h3> Modelo 2 </h3>

# %%
configuracao('grafico2')
sns.set_theme(style="darkgrid")
sns.lineplot(data=dataset,
             x=x,
             y=y,
             color='#B22222',
             
             linestyle='dashdot',
             linewidth=2,
             drawstyle='steps',
             marker='s', 
             markerfacecolor='#8B0000',
             markersize=13,
             fillstyle='bottom')
# Out:
# <AxesSubplot:title={'center':'Balanço de pagamentos - ativos de reserva por ano'}, xlabel='Ano', ylabel='Balanço de pagamentos - ativos de reserva '>

# %% [markdown]
# <h3> Referências </h3>
#
# <i>
# Dados do Balanço de pagamentos - ativos de reserva: http://www.ipeadata.gov.br/ <br>
# Biblioteca Matplotliba: https://matplotlib.org/ <br>
# Biblioteca Seaborna: https://seaborn.pydata.org/ <br>
# Tabela de Coresa https://celke.com.br/artigo/tabela-de-cores-html-nome-hexadecimal-rgb <br>
# Vídeos: https://www.youtube.com/watch?v=fZT-mG0_4DQ <br>
